# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\RAHUL\Desktop\New project\Taiyo.ai task-20230305T142417Z-001\Taiyo.ai task\world_bank_projects.csv")

# %%
df.head()
# Out:
#   Project Id                       Region                          Country  \
# 0    P161086                   South Asia  People's Republic of Bangladesh
# 1    P173281  Latin America and Caribbean                Republic of Haiti
# 2    P173746        East Asia and Pacific       People's Republic of China
# 3    P163836  Eastern and Southern Africa               Republic of Uganda
# 4    P158079        East Asia and Pacific       People's Republic of China
#
#   Project Status                                       Project Name  \
# 0         Active  Bangladesh: Enhancing Digital Government & Eco...
# 1         Active  AF Haiti Rural Accessibility & Resilience Project
# 2         Active  Emerging Infectious Diseases Prevention, Prepa...
# 3         Active   Irrigation for Climate Resilience Project (ICRP)
# 4         Active        China: Jiangxi Eco-industrial Parks Project
#
#                        Project Development Objective  \
# 0  To improve the efficiency and cybersecurity of...
# 1  The Project Development Objectives are to: (i)...
# 2  The proposed project development objective is ...
# 3  To provide farmers in the project areas with a...
# 4  To strengthen Jiangxi’s institutional and regu...
#
#                                  Implementing Agency  \
# 0                        Bangladesh Computer Council
# 1  Unite Technique d'Execution, Unite Centrale d'...
# 2  Ministry of Agriculture and Rural Affairs, Hai...
# 3                  Ministry of Water and Environment
# 4  Fuzhou New Industries Zone, Jiangxi Developmen...
#
#   Consultant Services Required  \
# 0                           No
# 1                           No
# 2                           No
# 3                           No
# 4                           No
#
#                                          Project URL Board Approval Date  ...  \
# 0  https://projects.worldbank.org/en/projects-ope...       June 19, 2020  ...
# 1  https://projects.worldbank.org/en/projects-ope...       June 18, 2020  ...
# 2  https://projects.worldbank.org/en/projects-ope...       June 18, 2020  ...
# 3  https://projects.worldbank.org/en/projects-ope...       June 18, 2020  ...
# 4  https://projects.worldbank.org/en/projects-ope...       June 18, 2020  ...
#
#                           Borrower            Lending Instrument  \
# 0  People's Republic of Bangladesh  Investment Project Financing
# 1            The Republic of Haiti  Investment Project Financing
# 2       People's Republic of China  Investment Project Financing
# 3               Republic of Uganda  Investment Project Financing
# 4       People's Republic of China  Investment Project Financing
#
#   Environmental Assessment Category Environmental and Social Risk  \
# 0                                 B                           NaN
# 1                               NaN                           NaN
# 2                               NaN                   Substantial
# 3                                 A                           NaN
# 4                                 B                           NaN
#
#                                 Sector 1  \
# 0  Central Government (Central Agencies)
# 1            Rural and Inter-Urban Roads
# 2                              Livestock
# 3                Irrigation and Drainage
# 4                 Renewable Energy Solar
#
#                                             Sector 2  \
# 0  Public Administration - Information and Commun...
# 1             Public Administration - Transportation
# 2  Public Administration - Agriculture, Fishing &...
# 3  Agricultural Extension, Research, and Other Su...
# 4  Public Administration - Water, Sanitation and ...
#
#                                             Sector 3 Theme 1 Theme 2  \
# 0                                       ICT Services     NaN     NaN
# 1                                                NaN     NaN     NaN
# 2                                                NaN     NaN     NaN
# 3  Public Administration - Agriculture, Fishing &...     NaN     NaN
# 4                                           Forestry     NaN     NaN
#
#   Unnamed: 27
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Project Id                         500 non-null    object
#  1   Region                             1001 non-null   object
#  2   Country                            1001 non-null   object
#  3   Project Status                     1001 non-null   object
#  4   Project Name                       1001 non-null   object
#  5   Project Development Objective      1001 non-null   object
#  6   Implementing Agency                955 non-null    object
#  7   Consultant Services Required       1001 non-null   object
#  8   Project URL                        1001 non-null   object
#  9   Board Approval Date                1001 non-null   object
#  10  Project Closing Date               787 non-null    object
#  11  Last Stage Reached                 1 non-null      object
#  12  Financing Type                     1001 non-null   object
#  13  Total Project Cost $US             1001 non-null   object
#  14  IBRD Commitment $US                1 non-null      object
#  15  IDA Commitment $US                 1 non-null      object
#  16  Total IDA and IBRD Commitment $US  1001 non-null   object
#  17  Grant Amount $US                   299 non-null    object
#  18  Borrower                           959 non-null    object
#  19  Lending Instrument                 1001 non-null   object
#  20  Environmental Assessment Category  541 non-null    object
#  21  Environmental and Social Risk      213 non-null    object
#  22  Sector 1                           1001 non-null   object
#  23  Sector 2                           865 non-null    object
#  24  Sector 3                           531 non-null    object
#  25  Theme 1                            1 non-null      object
#  26  Theme 2                            1 non-null      object
#  27  Unnamed: 27                        501 non-null    object
# dtypes: object(28)
# memory usage: 219.1+ KB

# %%
df.shape
# Out:
# (1001, 28)

# %%
df.columns.unique()
# Out:
# Index(['Project Id', 'Region', 'Country', 'Project Status', 'Project Name',
#        'Project Development Objective', 'Implementing Agency',
#        'Consultant Services Required', 'Project URL', 'Board Approval Date',
#        'Project Closing Date', 'Last Stage Reached', 'Financing Type',
#        'Total Project Cost $US', 'IBRD Commitment $US', 'IDA Commitment $US',
#        'Total IDA and IBRD Commitment $US', 'Grant Amount $US', 'Borrower',
#        'Lending Instrument', 'Environmental Assessment Category',
#        'Environmental and Social Risk', 'Sector 1', 'Sector 2', 'Sector 3',
#        'Theme 1', 'Theme 2', 'Unnamed: 27'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Project Id                            501
# Region                                  0
# Country                                 0
# Project Status                          0
# Project Name                            0
# Project Development Objective           0
# Implementing Agency                    46
# Consultant Services Required            0
# Project URL                             0
# Board Approval Date                     0
# Project Closing Date                  214
# Last Stage Reached                   1000
# Financing Type                          0
# Total Project Cost $US                  0
# IBRD Commitment $US                  1000
# IDA Commitment $US                   1000
# Total IDA and IBRD Commitment $US       0
# Grant Amount $US                      702
# Borrower                               42
# Lending Instrument                      0
# Environmental Assessment Category     460
# Environmental and Social Risk         788
# Sector 1                                0
# Sector 2                              136
# Sector 3                              470
# Theme 1                              1000
# Theme 2                              1000
# Unnamed: 27                           500
# dtype: int64

# %%
df.nunique()
# Out:
# Project Id                           500
# Region                                 8
# Country                              118
# Project Status                         3
# Project Name                         500
# Project Development Objective        493
# Implementing Agency                  416
# Consultant Services Required           4
# Project URL                          501
# Board Approval Date                  278
# Project Closing Date                 117
# Last Stage Reached                     1
# Financing Type                         5
# Total Project Cost $US               194
# IBRD Commitment $US                    1
# IDA Commitment $US                     1
# Total IDA and IBRD Commitment $US    194
# Grant Amount $US                     109
# Borrower                             281
# Lending Instrument                     4
# Environmental Assessment Category      6
# Environmental and Social Risk          5
# Sector 1                              63
# Sector 2                              51
# Sector 3                              55
# Theme 1                                1
# Theme 2                                1
# Unnamed: 27                          501
# dtype: int64

# %%
df.isna().sum()
# Out:
# Project Id                            501
# Region                                  0
# Country                                 0
# Project Status                          0
# Project Name                            0
# Project Development Objective           0
# Implementing Agency                    46
# Consultant Services Required            0
# Project URL                             0
# Board Approval Date                     0
# Project Closing Date                  214
# Last Stage Reached                   1000
# Financing Type                          0
# Total Project Cost $US                  0
# IBRD Commitment $US                  1000
# IDA Commitment $US                   1000
# Total IDA and IBRD Commitment $US       0
# Grant Amount $US                      702
# Borrower                               42
# Lending Instrument                      0
# Environmental Assessment Category     460
# Environmental and Social Risk         788
# Sector 1                                0
# Sector 2                              136
# Sector 3                              470
# Theme 1                              1000
# Theme 2                              1000
# Unnamed: 27                           500
# dtype: int64

# %%
df
# Out:
#      Project Id                       Region                          Country  \
# 0       P161086                   South Asia  People's Republic of Bangladesh
# 1       P173281  Latin America and Caribbean                Republic of Haiti
# 2       P173746        East Asia and Pacific       People's Republic of China
# 3       P163836  Eastern and Southern Africa               Republic of Uganda
# 4       P158079        East Asia and Pacific       People's Republic of China
# ...         ...                          ...                              ...
# 996         NaN  Eastern and Southern Africa               Republic of Rwanda
# 997         NaN      Europe and Central Asia                          Georgia
# 998         NaN  Eastern and Southern Africa           Republic of Mozambique
# 999         NaN  Latin America and Caribbean             Republic of Colombia
# 1000        NaN        East Asia and Pacific       People's Republic of China
#
#      Project Status                                       Project Name  \
# 0            Active  Bangladesh: Enhancing Digital Government & Eco...
# 1            Active  AF Haiti Rural Accessibility & Resilience Project
# 2            Active  Emerging Infectious Diseases Prevention, Prepa...
# 3            Active   Irrigation for Climate Resilience Project (ICRP)
# 4            Active        China: Jiangxi Eco-industrial Parks Project
# ...             ...                                                ...
# 996          Closed  Improving the Efficiency and Sustainability of...
# 997          Active  East West Highway Corridor Improvement Project...
# 998          Closed  Mining and Gas Technical Assistance Additional...
# 999          Active  Additional Financing Forest Conservation and S...
# 1000         Active      China: Guangdong Compulsory Education Project
#
#                           Project Development Objective  \
# 0     To improve the efficiency and cybersecurity of...
# 1     The Project Development Objectives are to: (i)...
# 2     The proposed project development objective is ...
# 3     To provide farmers in the project areas with a...
# 4     To strengthen Jiangxi’s institutional and regu...
# ...                                                 ...
# 996   The project development objective is to improv...
# 997   <p>The proposed PDOs are to: (i) reduce road u...
# 998   The proposed project development objective is ...
# 999   The project's global environmental objective (...
# 1000  The project development objective is to improv...
#
#                                     Implementing Agency  \
# 0                           Bangladesh Computer Council
# 1     Unite Technique d'Execution, Unite Centrale d'...
# 2     Ministry of Agriculture and Rural Affairs, Hai...
# 3                     Ministry of Water and Environment
# 4     Fuzhou New Industries Zone, Jiangxi Developmen...
# ...                                                 ...
# 996   Rwanda Environment Management Authority (REMA)...
# 997   Roads Department of the Ministry of Regional D...
# 998                                                 NaN
# 999                                                 NaN
# 1000                  Guangdong Department of Education
#
#      Consultant Services Required  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
# ...                           ...
# 996                           Yes
# 997                           Yes
# 998                           Yes
# 999                           Yes
# 1000                          Yes
#
#                                             Project URL Board Approval Date  \
# 0     https://projects.worldbank.org/en/projects-ope...       June 19, 2020
# 1     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 2     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 3     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 4     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# ...                                                 ...                 ...
# 996   https://projects.worldbank.org/en/projects-ope...   November 14, 2017
# 997   https://projects.worldbank.org/en/projects-ope...    November 8, 2017
# 998   https://projects.worldbank.org/en/projects-ope...    November 1, 2017
# 999   https://projects.worldbank.org/en/projects-ope...    October 31, 2017
# 1000  https://projects.worldbank.org/en/projects-ope...    October 31, 2017
#
#       ...                         Borrower            Lending Instrument  \
# 0     ...  People's Republic of Bangladesh  Investment Project Financing
# 1     ...            The Republic of Haiti  Investment Project Financing
# 2     ...       People's Republic of China  Investment Project Financing
# 3     ...               Republic of Uganda  Investment Project Financing
# 4     ...       People's Republic of China  Investment Project Financing
# ...   ...                              ...                           ...
# 996   ...               Republic of Rwanda  Investment Project Financing
# 997   ...                              NaN  Investment Project Financing
# 998   ...                              NaN  Investment Project Financing
# 999   ...                              NaN  Investment Project Financing
# 1000  ...       PEOPLE'S REPUBLIC OF CHINA  Investment Project Financing
#
#      Environmental Assessment Category Environmental and Social Risk  \
# 0                                    B                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                   Substantial
# 3                                    A                           NaN
# 4                                    B                           NaN
# ...                                ...                           ...
# 996                                NaN                           NaN
# 997                                  A                           NaN
# 998                                  B                           NaN
# 999                                  B                           NaN
# 1000                                 B                           NaN
#
#                                                Sector 1  \
# 0                 Central Government (Central Agencies)
# 1                           Rural and Inter-Urban Roads
# 2                                             Livestock
# 3                               Irrigation and Drainage
# 4                                Renewable Energy Solar
# ...                                                 ...
# 996   Public Administration - Agriculture, Fishing &...
# 997                         Rural and Inter-Urban Roads
# 998                                         Oil and Gas
# 999                                            Forestry
# 1000                                Secondary Education
#
#                                                Sector 2  \
# 0     Public Administration - Information and Commun...
# 1                Public Administration - Transportation
# 2     Public Administration - Agriculture, Fishing &...
# 3     Agricultural Extension, Research, and Other Su...
# 4     Public Administration - Water, Sanitation and ...
# ...                                                 ...
# 996                                            Forestry
# 997              Public Administration - Transportation
# 998      Public Administration - Energy and Extractives
# 999   Public Administration - Agriculture, Fishing &...
# 1000                                  Primary Education
#
#                                                Sector 3 Theme 1 Theme 2  \
# 0                                          ICT Services     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3     Public Administration - Agriculture, Fishing &...     NaN     NaN
# 4                                              Forestry     NaN     NaN
# ...                                                 ...     ...     ...
# 996                            Renewable Energy Biomass     NaN     NaN
# 997                                                 NaN     NaN     NaN
# 998                                              Mining     NaN     NaN
# 999                                                 NaN     NaN     NaN
# 1000                                       ICT Services     NaN     NaN
#
#      Unnamed: 27
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 996      P163358
# 997      P160152
# 998      P161683
# 999      P158003
# 1000     P154621
#
# [1001 rows x 28 columns]

# %%
# drop column 'C'
df = df.drop(['Last Stage Reached','IBRD Commitment $US','IDA Commitment $US','Theme 1','Theme 2','Environmental Assessment Category','Environmental and Social Risk'], axis=1)

# %%
df.head(2)
# Out:
#   Project Id                       Region                          Country  \
# 0    P161086                   South Asia  People's Republic of Bangladesh
# 1    P173281  Latin America and Caribbean                Republic of Haiti
#
#   Project Status                                       Project Name  \
# 0         Active  Bangladesh: Enhancing Digital Government & Eco...
# 1         Active  AF Haiti Rural Accessibility & Resilience Project
#
#                        Project Development Objective  \
# 0  To improve the efficiency and cybersecurity of...
# 1  The Project Development Objectives are to: (i)...
#
#                                  Implementing Agency  \
# 0                        Bangladesh Computer Council
# 1  Unite Technique d'Execution, Unite Centrale d'...
#
#   Consultant Services Required  \
# 0                           No
# 1                           No
#
#                                          Project URL Board Approval Date  ...  \
# 0  https://projects.worldbank.org/en/projects-ope...       June 19, 2020  ...
# 1  https://projects.worldbank.org/en/projects-ope...       June 18, 2020  ...
#
#   Financing Type Total Project Cost $US Total IDA and IBRD Commitment $US  \
# 0          Other              305000000                         305000000
# 1            IDA                      0                                 0
#
#   Grant Amount $US                         Borrower  \
# 0              NaN  People's Republic of Bangladesh
# 1              NaN            The Republic of Haiti
#
#              Lending Instrument                               Sector 1  \
# 0  Investment Project Financing  Central Government (Central Agencies)
# 1  Investment Project Financing            Rural and Inter-Urban Roads
#
#                                             Sector 2      Sector 3 Unnamed: 27
# 0  Public Administration - Information and Commun...  ICT Services         NaN
# 1             Public Administration - Transportation           NaN         NaN
#
# [2 rows x 21 columns]

# %%
df['Consultant Services Required'].unique()
# Out:
# array(['No', 'Yes', 'TBD', 'Consultant Services Required'], dtype=object)

# %%
df
# Out:
#      Project Id                       Region                          Country  \
# 0       P161086                   South Asia  People's Republic of Bangladesh
# 1       P173281  Latin America and Caribbean                Republic of Haiti
# 2       P173746        East Asia and Pacific       People's Republic of China
# 3       P163836  Eastern and Southern Africa               Republic of Uganda
# 4       P158079        East Asia and Pacific       People's Republic of China
# ...         ...                          ...                              ...
# 996         NaN  Eastern and Southern Africa               Republic of Rwanda
# 997         NaN      Europe and Central Asia                          Georgia
# 998         NaN  Eastern and Southern Africa           Republic of Mozambique
# 999         NaN  Latin America and Caribbean             Republic of Colombia
# 1000        NaN        East Asia and Pacific       People's Republic of China
#
#      Project Status                                       Project Name  \
# 0            Active  Bangladesh: Enhancing Digital Government & Eco...
# 1            Active  AF Haiti Rural Accessibility & Resilience Project
# 2            Active  Emerging Infectious Diseases Prevention, Prepa...
# 3            Active   Irrigation for Climate Resilience Project (ICRP)
# 4            Active        China: Jiangxi Eco-industrial Parks Project
# ...             ...                                                ...
# 996          Closed  Improving the Efficiency and Sustainability of...
# 997          Active  East West Highway Corridor Improvement Project...
# 998          Closed  Mining and Gas Technical Assistance Additional...
# 999          Active  Additional Financing Forest Conservation and S...
# 1000         Active      China: Guangdong Compulsory Education Project
#
#                           Project Development Objective  \
# 0     To improve the efficiency and cybersecurity of...
# 1     The Project Development Objectives are to: (i)...
# 2     The proposed project development objective is ...
# 3     To provide farmers in the project areas with a...
# 4     To strengthen Jiangxi’s institutional and regu...
# ...                                                 ...
# 996   The project development objective is to improv...
# 997   <p>The proposed PDOs are to: (i) reduce road u...
# 998   The proposed project development objective is ...
# 999   The project's global environmental objective (...
# 1000  The project development objective is to improv...
#
#                                     Implementing Agency  \
# 0                           Bangladesh Computer Council
# 1     Unite Technique d'Execution, Unite Centrale d'...
# 2     Ministry of Agriculture and Rural Affairs, Hai...
# 3                     Ministry of Water and Environment
# 4     Fuzhou New Industries Zone, Jiangxi Developmen...
# ...                                                 ...
# 996   Rwanda Environment Management Authority (REMA)...
# 997   Roads Department of the Ministry of Regional D...
# 998                                                 NaN
# 999                                                 NaN
# 1000                  Guangdong Department of Education
#
#      Consultant Services Required  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
# ...                           ...
# 996                           Yes
# 997                           Yes
# 998                           Yes
# 999                           Yes
# 1000                          Yes
#
#                                             Project URL Board Approval Date  \
# 0     https://projects.worldbank.org/en/projects-ope...       June 19, 2020
# 1     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 2     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 3     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 4     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# ...                                                 ...                 ...
# 996   https://projects.worldbank.org/en/projects-ope...   November 14, 2017
# 997   https://projects.worldbank.org/en/projects-ope...    November 8, 2017
# 998   https://projects.worldbank.org/en/projects-ope...    November 1, 2017
# 999   https://projects.worldbank.org/en/projects-ope...    October 31, 2017
# 1000  https://projects.worldbank.org/en/projects-ope...    October 31, 2017
#
#       ... Financing Type Total Project Cost $US  \
# 0     ...          Other              305000000
# 1     ...            IDA                      0
# 2     ...           IBRD              350000000
# 3     ...          Other                      0
# 4     ...          Other              400000000
# ...   ...            ...                    ...
# 996   ...         Grants                3991436
# 997   ...          Other              130000000
# 998   ...         Grants               29000000
# 999   ...          Other               12000000
# 1000  ...          Other              279400000
#
#      Total IDA and IBRD Commitment $US Grant Amount $US  \
# 0                            305000000              NaN
# 1                                    0              NaN
# 2                            350000000              NaN
# 3                                    0              NaN
# 4                            400000000              NaN
# ...                                ...              ...
# 996                            3991436              NaN
# 997                          130000000       90,000,000
# 998                           29000000              NaN
# 999                           12000000              NaN
# 1000                         279400000              NaN
#
#                              Borrower            Lending Instrument  \
# 0     People's Republic of Bangladesh  Investment Project Financing
# 1               The Republic of Haiti  Investment Project Financing
# 2          People's Republic of China  Investment Project Financing
# 3                  Republic of Uganda  Investment Project Financing
# 4          People's Republic of China  Investment Project Financing
# ...                               ...                           ...
# 996                Republic of Rwanda  Investment Project Financing
# 997                               NaN  Investment Project Financing
# 998                               NaN  Investment Project Financing
# 999                               NaN  Investment Project Financing
# 1000       PEOPLE'S REPUBLIC OF CHINA  Investment Project Financing
#
#                                                Sector 1  \
# 0                 Central Government (Central Agencies)
# 1                           Rural and Inter-Urban Roads
# 2                                             Livestock
# 3                               Irrigation and Drainage
# 4                                Renewable Energy Solar
# ...                                                 ...
# 996   Public Administration - Agriculture, Fishing &...
# 997                         Rural and Inter-Urban Roads
# 998                                         Oil and Gas
# 999                                            Forestry
# 1000                                Secondary Education
#
#                                                Sector 2  \
# 0     Public Administration - Information and Commun...
# 1                Public Administration - Transportation
# 2     Public Administration - Agriculture, Fishing &...
# 3     Agricultural Extension, Research, and Other Su...
# 4     Public Administration - Water, Sanitation and ...
# ...                                                 ...
# 996                                            Forestry
# 997              Public Administration - Transportation
# 998      Public Administration - Energy and Extractives
# 999   Public Administration - Agriculture, Fishing &...
# 1000                                  Primary Education
#
#                                                Sector 3 Unnamed: 27
# 0                                          ICT Services         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3     Public Administration - Agriculture, Fishing &...         NaN
# 4                                              Forestry         NaN
# ...                                                 ...         ...
# 996                            Renewable Energy Biomass     P163358
# 997                                                 NaN     P160152
# 998                                              Mining     P161683
# 999                                                 NaN     P158003
# 1000                                       ICT Services     P154621
#
# [1001 rows x 21 columns]

# %%
# replace NaN values with 'Not available'
df.fillna('Not available', inplace=True)

# %%
df.sample(3)
# Out:
#     Project Id                        Region              Country  \
# 226    P166941       Europe and Central Asia              Ukraine
# 251    P162454  Middle East and North Africa     Republic of Iraq
# 311    P167583       Europe and Central Asia  Republic of Belarus
#
#     Project Status                                       Project Name  \
# 226         Active  Accelerating Private Investment in Agriculture...
# 251         Active  IQ: Basra Electricity Dissemination and Develo...
# 311         Closed  SUPPORT TO PREPARATION AND IMPLEMENTATION OF T...
#
#                          Project Development Objective  \
# 226  The Program Development Objective is to allevi...
# 251  To improve the reliability and operational and...
# 311  The project supports improved quality and avai...
#
#                                    Implementing Agency  \
# 226    Ministry of Agrarian Policy and Food of Ukraine
# 251  South Electricity Distribution Company, South ...
# 311  National Statistical Committee of the Republic...
#
#     Consultant Services Required  \
# 226                           No
# 251                          Yes
# 311                          TBD
#
#                                            Project URL Board Approval Date  \
# 226  https://projects.worldbank.org/en/projects-ope...        May 24, 2019
# 251  https://projects.worldbank.org/en/projects-ope...         May 2, 2019
# 311  https://projects.worldbank.org/en/projects-ope...    December 4, 2018
#
#      ... Financing Type Total Project Cost $US  \
# 226  ...          Other                      0
# 251  ...           IBRD                      0
# 311  ...         Grants                      0
#
#     Total IDA and IBRD Commitment $US Grant Amount $US             Borrower  \
# 226                                 0    Not available              Ukraine
# 251                                 0    Not available     Republic of Iraq
# 311                                 0        1,900,000  Republic of Belarus
#
#                 Lending Instrument                                 Sector 1  \
# 226  Program-for-Results Financing  Other Agriculture, Fishing and Forestry
# 251   Investment Project Financing     Energy Transmission and Distribution
# 311   Investment Project Financing    Central Government (Central Agencies)
#
#                                               Sector 2       Sector 3  \
# 226  Agricultural markets, commercialization and ag...  Not available
# 251     Public Administration - Energy and Extractives  Not available
# 311                                       ICT Services  Not available
#
#        Unnamed: 27
# 226  Not available
# 251  Not available
# 311  Not available
#
# [3 rows x 21 columns]

# %%
plt.plot(df['Region'])

# %%
plt.plot(df['Project Status'])

# %%
# Plot histogram of the different job titles in the dataset
sns.countplot(y= 'Project Name', data = df, order = df['Project Name'].value_counts().index)

# Add labels and titles
plt.xlabel('Count')
plt.ylabel('Project Name')
plt.title('Count Plot of Different Project Name Titles')

plt.show()

# %%
df['Project Name'].unique()
# Out:
# array(['Bangladesh: Enhancing Digital Government & Economy Project',
#        'AF Haiti Rural Accessibility & Resilience Project',
#        'Emerging Infectious Diseases Prevention, Preparedness and Response Project',
#        'Irrigation for Climate Resilience Project (ICRP)',
#        'China: Jiangxi Eco-industrial Parks Project',
#        'Second District Heating Efficiency Improvement Project',
#        'Cameroon - Chad Power Interconnection Project',
#        'Supporting Egypt’s Universal Health Insurance System',
#        'Improving Primary Health in Rural Areas and Responding to COVID-19 Pandemic Emergency',
#        'Water Security in the Dry Corridor of Honduras',
#        'Chad Local Development and Adaptation Project',
#        'Fourth Additional Financing for Health System Strengthening for Better Maternal and Child Health Results Project',
#        'Nepal Strategic Road Connectivity and Trade Improvement Project',
#        'Wastewater Management Sustainability Project',
#        'FSM Maritime Investment Project Additional Financing',
#        'GAMBIA FISCAL MANAGEMENT DEVELOPMENT PROJECT',
#        'Pakistan Community Support Project (CASA-1000)',
#        'Maldives Learning Advancement and Measurement Project',
#        'Development Response to Displacement Impacts Project in the Horn of Africa',
#        'Caribbean Ocean and Aquaculture Sustainability FaciliTy (COAST) Project',
#        'Emergency Response and Nafa Program Support Project',
#        'Power System Efficiency and Resilience Project',
#        'Irrigation Development Support Project - Additional Financing',
#        'Dominica - Caribbean Regional Air Transport Connectivity Project',
#        'Caribbean Regional Air Transport Connectivity Project - Haiti',
#        'Additional Financing for MCRP',
#        'ID: Strengthening of Social Forestry in Indonesia',
#        'Institutional Foundations to Improve Services For Health',
#        'Zambia Education Enhancement Project',
#        'Belarus Higher Education Modernization Project',
#        'Emergency Locust Response Program',
#        'Additional Financing for the Second Regional and Municipal Infrastructure Development Project',
#        'Tamil Nadu Housing and Habitat Development Project',
#        'Sri Lanka Integrated Watershed and Water Resources Management Project',
#        'Additional Financing for Indonesia Social Assistance Reform Program',
#        'Additional Financing to Rwanda Quality Basic Education for Human Capital Development Project',
#        'Egypt COVID-19 Emergency Response',
#        'Climate Adaptation and Resilience for South Asia',
#        'AGRICULTURE AND LIVESTOCK COMPETITIVENESS PROGRAM FOR RESULTS',
#        "Cote d'Ivoire COVID-19 Strategic Preparedness and  Response Project (SPRP)",
#        'North Macedonia Emergency COVID-19 Response Project',
#        'Early Childhood Development to Build Tajikistan’s Human Capital Project',
#        'EU4Innovation STEM Project',
#        'Malawi Governance to Enable Service Delivery Project',
#        'West Africa Unique Identification for Regional Integration and Inclusion - Phase 2',
#        'Burkina Faso COVID-19 Preparedness and Response Project',
#        'Mongolia Third Sustainable Livelihoods Project - Additional Financing',
#        'Ulaanbaatar Heating Sector Improvement Project',
#        'Uganda Investing in Forests and Protected Areas for Climate-Smart Development Project',
#        'São Paulo Aricanduva Bus Rapid Transit Corridor',
#        'Philippines COVID-19 Emergency Response Project',
#        'PNG Agriculture Commercialization and Diversification Project',
#        'Eswatini COVID-19 Emergency Response Project',
#        'Central African Republic COVID-19 Preparedness and Response Project',
#        'Republic of Congo COVID-19 Emergency Response Project',
#        'Bhutan: COVID-19 Emergency Response and Health Systems Preparedness Project',
#        'El Salvador COVID-19 Emergency Response Project',
#        'Togo COVID-19 Emergency Response and Systems Preparedness Strengthening Project',
#        'RMI COVID-19 Emergency Response Project',
#        'Extractive Industries Accountability and Governance Enhancement Project',
#        'Myanmar COVID-19 Emergency Response Project',
#        'Malawi COVID-19 Emergency Response and Health Systems Preparedness Project',
#        'Niger COVID-19 Emergency Response Project',
#        'Transition to Electromobility in Brazilian Cities',
#        'MALI COVID-19 EMERGENCY RESPONSE PROJECT',
#        'Liberia COVID-19 Emergency Response Project',
#        'Power Sector Recovery Project Additional Financing',
#        'Lao PDR COVID-19 Response Project',
#        'Bangladesh: COVID-19 Emergency Response and Pandemic Preparedness Project',
#        'Additional Financing to Heat Supply Improvement Project',
#        'Ecuador COVID-19 Emergency Response and Vaccination Project',
#        'Yemen COVID-19 Response Project', 'Djibouti COVID-19 Response',
#        'Haiti COVID-19 Response',
#        'STP COVID-19 Emergency Response Project',
#        'MONGOLIA COVID-19 EMERGENCY RESPONSE AND HEALTH SYSTEM PREPAREDNESS PROJECT',
#        'India COVID-19 Emergency Response and Health Systems Preparedness Project',
#        'Kyrgyz Republic - Emergency COVID-19 Project',
#        'Mauritania COVID-19 Strategic Preparedness and Response Project (SPRP)',
#        'Cambodia COVID-19 Emergency Response Project',
#        'Senegal COVID-19 Response Project',
#        'Tanzania Secondary Education Quality Improvement Project (SEQUIP)',
#        'Learning for the Future Project',
#        'Health and Gender Support Project for Cox’s Bazar district',
#        'Safety Net Systems for the Poorest (AF) (IDA18 RSW)',
#        'Decentralization and Productive Intermediate Cities Support Project',
#        'Health System Support Additional Financing',
#        'SPF - Support to Zimbabwe Recovery and Resilience',
#        "Additional Financing for Girls' Education and Women's Empowerment and Livelihood Project (GEWEL)",
#        'Green National Highways Corridor Project',
#        'Digital Federated States of Micronesia Project',
#        'CARIBBEAN REGIONAL COMMUNICATIONS INFRASTRUCTURE PROGRAM ADDITIONAL FINANCING',
#        'Costa Rica Fiscal Management Improvement Project',
#        'Additional Financing for Judicial Services & Smart Infrastructure Project',
#        'Costa Rica Sustainable Fisheries Development Project',
#        'Additional Financing to the Malawi Resilience and Disaster Risk Management Project',
#        'Second Additional Financing for the Children and Youth Protection Project',
#        'Linha de Crédito para Resiliência Urbana no Sul do Brasil',
#        'Improving Mobility and Urban Inclusion in the Amazonas Corridor in Belo Horizonte',
#        'EG Inclusive Housing Finance Program Additional Financing',
#        'Jordan Youth, Technology, and Jobs Project',
#        'Agriculture Modernization Project',
#        'Additional Financing for the Armenia Social Investment and Local Development Project',
#        'Improving Quality of Health Care Services and Efficiency in Colombia',
#        'Growing up Healthy Together: Comprehensive Early Childhood Development in El Salvador',
#        'Growing Up and Learning Together: Comprehensive Early Childhood Development in El Salvador',
#        'Kyrgyz Republic Regional Economic Development Project',
#        'Water Services and Institutional Support Project',
#        'Kiribati: Pacific Islands Regional Oceanscape Program',
#        'Marine Fisheries and Socio-Economic Development Project',
#        'Cap Haitien Urban Development Project',
#        'Employment Support Project',
#        'Balochistan Livelihoods and Entrepreneurship Project',
#        'Strengthening Institutions for Refugee Administration Project',
#        'Inclusive Access and Quality Education project',
#        'COMPETITIVENESS AND ENTERPRISE DEVELOPMENT PROJECT',
#        'Solar Energy in Local Communities',
#        'Renewable Energy Integration Project Additional Financing',
#        'Albania Environmental Services Project',
#        'Additional Financing to Rural Development Program II',
#        'Ogun State Economic Transformation Project',
#        'Innovation Development and Effectiveness in the Acquisition of Skills (IDEAS) Project',
#        'Integrated Project for Source Sustainability and Climate Resilient Rain-fed Agriculture in Himachal Pradesh',
#        'Sustainable Procurement, Environmental and Social Standards Enhancement Project (SPESSE)',
#        'Statistical Innovation and Capacity Building in Tonga',
#        'Statistical Innovation and Capacity Building in the Pacific Islands',
#        'Water Security Development - Gaza Central Desalination Program – Associated Works Phase I Project',
#        'Social Insurance Administration Project',
#        'Modernization of Public Financial Management Systems in Mexico',
#        'North Macedonia Public Sector Energy Efficiency Project',
#        'Vanuatu Climate Resilient Transport Project',
#        "Dedicated Grant Mechanism for Cote d'Ivoire",
#        'SWEDD Additional Financing for Chad',
#        'National Urban Cadaster and Municipal Support Project',
#        'North Macedonia: Local Roads Connectivity Project',
#        'Forest Ecosystem Improvement in the Upper Reaches of Yangtze River Basin Program',
#        'Assam Inland Water Transport Project',
#        'Livestock Commercialization Project',
#        'South Tarawa Water Supply Project',
#        'Serbia Accelerating Innovation and Growth Entrepreneurship',
#        'West Bengal Major Irrigation and Flood Management Project',
#        'Africa CDC Regional Investment Financing Project',
#        'Improvement of Solid Waste Management to Support Regional and Metropolitan Cities',
#        'Serbia Competitive Agriculture Project (SCAP)',
#        'Strengthening Reform Management in Jordan',
#        'Indonesia Disaster Resilience Initiatives Project (IDRIP)',
#        'Second Africa Higher Education Centers of Excellence for Development Impact',
#        'Afghanistan Gas Project (AGASP)',
#        'Real Estate Management Project Additional Financing',
#        'Additional Financing - Regional Disease Surveillance Systems Enhancement Project in West Africa, Phase 1 (REDISSE 1)',
#        'Climate Smart Management of Grassland Ecosystems',
#        'Socio-economic Reintegration Project in Southern Thailand',
#        'Second Rural Economic Development Initiative (REDI II) Project',
#        'Improving the Livelihoods of Miskito Indigenous Peoples in La Moskitia',
#        'Turkey Energy Efficiency in Public Buildings',
#        'Support for Preparation of the Rural Electrification, Sebzor HPP and Khorog-Qozideh Power Transmission Line Projects',
#        'Regional Disease Surveillance Systems Enhancement Project (REDISSE) Phase IV',
#        'Expanding Opportunities for Learning',
#        'Odisha Integrated Irrigation Project for Climate Resilient Agriculture',
#        'Improved Feeding Practices for first 1,000 Days',
#        'Vietnam: Strengthening Banking Sector Soundness and Development',
#        'Tanzania Productive Social Safety Net Project II',
#        'Youth Employment Transformation Initiative Project',
#        'Enhancing Capital Markets Supervision Capacities of The Albanian Financial Supervisory Authority Phase 2',
#        'Matanza-Riachuelo Basin (MRB) Sustainable Development Project Additional Financing',
#        'Investing in Early Years and Fertility in Burundi (NKURIZA)',
#        'Social Safety Nets for Vulnerable Populations in the Province of Buenos Aires',
#        'Burkina Faso Agriculture Resilience and Competitiveness Project',
#        'OECS Regional Health Project',
#        'IMPLEMENTING CHANGE MANAGEMENT STRATEGY FOR EGP AND BUILDING CAPACITY FOR PPDA AND ITS STAKEHOLDERS',
#        'Statistical Capacity EU Grant',
#        'Rwanda Quality Basic Education for Human Capital Development Project',
#        'Additional Financing to the Mali Rural Electrification Hybrid System Project',
#        'Real Estate Registration Project',
#        'Balochistan Education Project',
#        'Benin Global Partnership for Education Project Phase 3',
#        'Bangladesh Municipal Water Supply and Sanitation Project',
#        'Rural Electrification Project',
#        'Competitiveness and Sector Diversification',
#        'Additional Financing to the Agriculture and Natural Resources  Landscape Management Project (SUSTENTA)',
#        'Strengthening Social Safety Net Additional Financing',
#        'Samoa Agriculture & Fisheries Productivity and Marketing Project (SAFPROM)',
#        'Sierra Leone SSN Project Second Additional Financing',
#        'Digital Rural Transformation Project',
#        'Somalia - Water for Agro-pastoral Productivity and Resilience',
#        'Africa Climate Resilience Investment Facility',
#        'Karachi Mobility Project',
#        'Urban Water Supply and Sanitation Project',
#        'Competitive and Livable City of Karachi Project',
#        'Network Reinforcement and Access Project',
#        'Khyber Pakhtunkhwa Integrated Tourism Development Project',
#        'Social Welfare Development and Reform Project II Additional Financing',
#        'Institutional Strengthening for Improved Village Service Delivery',
#        'Climate Resilience Multi-Phase Programmatic Approach',
#        'Tunisia Energy Sector Improvement Project',
#        'Mali Electricity Sector  Improvement Project (MESIP)',
#        'Mali Governance of Mining Sector',
#        'Support to the Preparation of Egypt’s First National Strategy for Development of Statistics',
#        'Rural Economy Development Project',
#        'Disaster Risk Management in Schools Project',
#        'Education Support Program',
#        'Central Sulawesi Rehabilitation and Reconstruction Project',
#        'Metropolitan Buenos Aires Urban Transformation Project Additional Financing',
#        'Maldives: Enhancing Employability and Resilience of Youth Project',
#        'Digital Transformation for User-Centric Public Services',
#        'Liberia Urban Water Supply Project Additional Financing',
#        'Belarus Utility Efficiency and Quality Improvement Project',
#        'Integrated and Resilient Urban Mobility Project',
#        'One WASH—Consolidated Water Supply, Sanitation, and Hygiene Account Project (One WASH—CWA)',
#        'Pakistan Raises Revenue',
#        'Khyber Pakhtunkhwa Revenue Mobilization and Public Resource Management',
#        'National Urban Development Project (NUDP)',
#        'Vietnam - Dynamic Cities Integrated Development Project',
#        'Primary Health Care Quality Improvement Program',
#        'Improved Forested Landscape Management Project (GEF AF)',
#        'Improving the Performance of Non-Criminal Justice Services',
#        'Child Health Expansion Angola',
#        'Higher Education Development in Pakistan',
#        'CAR: LONDO "Stand Up" Project',
#        'Smallholder Agriculture Development Project - II',
#        'Scale-Up and Responding to the needs of Refugees and Host Communities',
#        'Improving Resilience and Emergency Response Project',
#        'Strengthening Preparedness and Critical Emergency Infrastructure Project',
#        'Greater Accra Resilient and Integrated Development Project',
#        'Shaanxi Sustainable Towns Development Project',
#        'Accelerating Private Investment in Agriculture Program',
#        'The Gambia Social Safety Net Project',
#        'Energy Supply Reliability and Financial Recovery Guarantee',
#        'Additional Financing for the Third Municipal Development Project',
#        'Lowlands Livelihood Resilience Project',
#        'Integrated Development and Competitiveness Project',
#        'CAR-Agriculture Recovery and Agribusiness Development Support Project (ARADSP)',
#        'Sierra Leone Energy Sector Utility Reform Project Additional Financing',
#        'Lesotho Lowlands Water Development Project - Phase II',
#        'Nouadhibou Eco-Seafood Cluster Project AF',
#        'Urban Water Supply and Sanitation Sector Project',
#        'Strengthening Primary Health Care and Surveillance in Haiti',
#        'Strengthening DRM and Climate Resilience Project',
#        'Rwanda - Additional Financing for the Transformation of Agriculture Sector Program 4 PforR Phase 2',
#        'Integrated Cash Transfer and Human Capital Project',
#        'Yemen Emergency Health and Nutrition Project Third Additional Financing',
#        'Emergency Crisis Response Project Fourth Additional Financing',
#        'Supporting the economic inclusion of youth',
#        'Federated States of Micronesia Maritime Investment Project',
#        'Marshall Islands Maritime Investment Project',
#        'Samoa Aviation Investment Project Additional Finance II',
#        'LIFELINE ROAD NETWORK IMPROVEMENT PROJECT - Second Additional Financing',
#        'China Distributed Renewable Energy Scale-Up Project',
#        'Improving Health Sector Performance Project Second Additional Financing',
#        'Additional Financing for Ghana Forest Investment Program (FIP) - Enhancing Natural Forest and Agroforest Landscapes Project',
#        'IQ: Basra Electricity Dissemination and Development Project (EDDP)',
#        'Social Protection Integration',
#        'Financial Inclusion Support Project in Burkina Faso',
#        'Socio-economic Inclusion of Refugees & Host Communities in Rwanda Project',
#        'Afghanistan Land Administration System Project',
#        'Tax Administration Modernization Project',
#        'Enabling Digital Governance Project',
#        'Belarus Education Modernization Project - Additional Financing',
#        'El Salvador Local Economic Resilience Project',
#        'Tonga: Pathway to Sustainable Oceans',
#        'China Partnership for Market Readiness',
#        'Enhancing Government Effectiveness for Improved Public Services',
#        'Sint Maarten Enterprise Support Project',
#        'Program Towards Elimination of Tuberculosis',
#        'Dhaka City Neighborhood Upgrading Project',
#        'Guyana Petroleum Resources Governance and Management Project',
#        'Strategic Purchasing and Alignment of Resources & Knowledge in Health Project (SPARK-Health)',
#        'Sao Tome e Principe Transport Sector Development and Coastal Protection Project',
#        'Mozambique Disaster Risk Management and Resilience Program',
#        'Mali - Accelerating Progress Towards Universal Health Coverage',
#        'Dominica Geothermal Risk Mitigation Project',
#        'Enhancing Public Finance Management through Information and Communication Technology and Skills (E-FITS) Project',
#        'Reducing Rural Poverty and Malnutrition Project',
#        'Local Development Support Project',
#        'Bangladesh Scaling-up Renewable Energy Project',
#        'Madagascar  - Least-Cost Electricity Access Development Project - LEAD',
#        'CAR Emergency Electricity Supply and Access Project',
#        'Paraiba Improving Water Resources Management and Services Provision',
#        'Multisectoral Early Childhood Development Project',
#        'Dam Rehabilitation & Improvement Project - Restructuring and Additional Financing',
#        'AF III DRC Health System Strengthening for Better Maternal and Child Health Results',
#        'Framework Development and Infrastructure Financing to Support Public-Private Partnerships Project',
#        'AF - Ghana: Public Financial Management Reform Project - Additional Financing',
#        'LISUNGI Safety Nets System Project II',
#        'Partnership for Market Readiness 2 Project',
#        'Nepal:  Private Sector-Led Mini-Grid Energy Access Project',
#        'SWEDD Additional Financing for Benin',
#        'Vietnam HCFC Phaseout Project Stage II',
#        'Sierra Leone Financial Inclusion Project',
#        'TV: Telecommunications and ICT Development Project',
#        'Smallholder Agriculture Transformation and Agribusiness Revitalization Project (STAR-P)',
#        'Integrated Forest Landscape Management Project',
#        'Niger Adaptive Safety Net Project 2',
#        'Senegal - Additional Financing to the Social Safety Net Project',
#        'VIETNAM QUALITY IMPROVEMENT OF PRIMARY EDUCATION FOR DEAF CHILDREN PROJECT (QIPEDC)',
#        'Revenue Administration Reform Support (RARS)',
#        'Sint Maarten Emergency Debris Management Project',
#        'Tackling Afghanistan’s Government HRM and Institutional Reforms',
#        'Cities Investment Program',
#        'Medium-Size Cities Integrated Urban Development Project',
#        'Additional Financing for Health Equity and Quality Improvement Project (H-EQIP)',
#        'SABESP - IMPROVING WATER SERVICE ACCESS AND SECURITY IN THE METROPOLITAN REGION OF SÃO PAULO PROJECT',
#        'Real Estate & Geospatial Infrastructure Project',
#        'China HCFC Phaseout Project Stage II',
#        'Yemen Emergency Crisis Response Project - Third Additional Financing',
#        'Additional Financing - Support to the National Education Pact Project',
#        'Social Inclusion Project',
#        'Jharkhand Municipal Development Project',
#        'Decentralizing Funding to Schools Project',
#        'Livestock and Dairy Development Project',
#        'SUPPORT TO PREPARATION AND IMPLEMENTATION OF THE 2019 POPULATION CENSUS IN BELARUS',
#        'Mozambique Land Administration Project (Terra Segura)',
#        'Burkina Faso: Emergency Recurrent Cost Financing Project',
#        'Kenya Social and Economic Inclusion Project',
#        'Somali Urban Investment Planning Project Additional Financing',
#        'Improving Youth Employability Through Informal Apprenticeship',
#        'Cabo Verde Education and Skills Development Enhancement Project',
#        'Somalia Inclusive Community Resilience and GBV Pilot',
#        'Rwanda Public Finance Management Reform Project',
#        'Public Sector Reform for Results Project',
#        'Second MDTF for Capacity Building Support to Implement the IPS',
#        'Sustainable Forests & Livelihoods (SUFAL) Project',
#        'Jharkhand Power System Improvement Project',
#        'SAMOA - Pacific Resilience Project under Pacific Resilience Program Additional Finance',
#        "Women's Economic Empowerment Rural Development Project", 'EQRA',
#        'CAR Health System Support and Strengthening (SENI) Project',
#        'Strengthening Climate Resilience in Burkina Faso',
#        'Food and Nutrition Security Enhancement Project',
#        'Ghana Secondary Cities Support Program',
#        'AF to Sustainable Rural Sanitation Services Program',
#        'Mozambique Conservation Areas for Biodiversity and Development - Phase 2',
#        'Ghana Financial Sector Development Project',
#        'Additional Financing for Reaching Out of School Children II',
#        'Additional Financing for the Higher Education Development Project',
#        'Samoa Climate Resilient Transport Project',
#        'ESV:Addressing Non-Communicable Diseases',
#        'Niger Refugees and Host Communities Support Project',
#        'Additional Financing Uganda Reproductive Maternal and Child Health Services Improvement Project',
#        'Chad - Refugees and Host Communities Support Project',
#        'Supporting Critical Infrastructure Resilience and Disaster-Risk Awareness in Turkey',
#        'Land Registration and Property Valuation Project',
#        'DRC - Gender Based Violence Prevention and Response Project',
#        'Monitoring Post Ebola Recovery Funds: A Focus on Service Delivery',
#        'Skills and Employment for Tongans',
#        'Gaza Emergency Cash for Work and Self-Employment Support',
#        'Myanmar RBF for Off-grid Solar',
#        'Central Asia Hydrometeorology Modernization Project (CAHMP) Additional Financing',
#        'Tunisia-Italy Power Interconnector - Project Preparation TA',
#        'Ethiopia Resilient Landscapes and Livelihoods Project',
#        'Modernization of Water Supply and Sanitation Services',
#        'Strengthening Disaster Risk Management Project',
#        'Ghana Energy Sector Transformation Initiative Project',
#        'Burkina Faso Higher Education Support Project',
#        'Sierra Leone Agro-Processing Competitiveness Project',
#        'Guinea Integrated Agricultural Development Project (PDAIG)',
#        'Towards Zero Stunting and Responding to COVID-19 and Other Emergencies',
#        'DRC- SME Development and Growth Project',
#        'Chad Digitalization of Revenue Administrations and COVID-19 Response Project',
#        'Community and Local Government Basic Social Services Project',
#        'Africa Regional Scholarship and Innovation Fund for Applied Sciences, Engineering and Technology',
#        'OECS MSME Guarantee Facility Project',
#        'GEF Electricity Access and Renewable Energy Expansion Project',
#        'Mali Drylands Development Project',
#        'Kosovo Digital Economy (KODE)',
#        'Financial Instruments for Brazil Energy Efficient Cities - FinBRAZEEC',
#        'Promoting Inclusion of Persons with Disabilities in Social Protection and Employment Programs',
#        'Productive Inclusion Project',
#        'Nigeria Erosion and Watershed Management Project (NEWMAP) - Additional Financing',
#        'Sri Lanka: Primary Health Care System Strengthening Project',
#        'Integrated Public Financial Management Reform Project',
#        'Myanmar National Community Driven Development Project',
#        'Nigeria Polio Eradication Support Project Additional Financing',
#        'Nigeria- Accelerating Nutrition Results',
#        'Public-Private Partnerships and Public Investment Advisory Project',
#        'Burkina Faso Water Supply and Sanitation Program',
#        'Additional Financing Quito Metro Line One Project',
#        'Senegal Rural Water Supply and Sanitation Project',
#        'Additional Financing - Second Water Institutional Development Project',
#        'Strategic Irrigation Modernization and Urgent Rehabilitation Project',
#        'Road Asset Management Project II Additional Financing',
#        'Investing in Nutrition and Early Years',
#        'Anhui Aged Care System Demonstration Project',
#        'Kenya Industry and Entrepreneurship',
#        'Youth Employment and Productive Inclusion Project',
#        'Khyber Pass Economic Corridor Project',
#        'Health Service Delivery Network Project',
#        'Indonesia - Supporting Primary Health Care Reform',
#        'Hezhou Urban Water Infrastructure and Environment Improvement Project',
#        'Djibouti Support for Women and Youth Entrepreneurship',
#        'Morocco - Noor Solar Power Project Additional Financing',
#        'Maldives Public Financial Management Systems Strengthening Project',
#        'Somali Petroleum Technical Assistance Project (SOPTAP)',
#        'Jiangxi Integrated Rural and Urban Water Supply and Wastewater Management Project',
#        'National Urban Water Supply Project',
#        'China: Liaoning Safe and Sustainable Urban Water Supply Project',
#        'West Africa Unique Identification for Regional Integration and Inclusion (WURI) Program',
#        'STATE OWNED ENTERPRISES RELATED FISCAL MANAGEMENT PROJECT',
#        "Cote d'Ivoire: Education Service Delivery Enhancement Project",
#        'Public Financial Management Improvement Project',
#        'Innovative Private Sector Development',
#        'Guinea-Bissau Strengthening Maternal and Child Health Service Delivery',
#        'Support to Enterprise Development and Competitiveness  Project',
#        'Project for Strengthening Public Financial Management',
#        'Integrated Infrastructure Development for National Tourism Strategic Areas (Indonesia Tourism Development Project)',
#        'Angola Commercial Agriculture Development Project (PDAC)',
#        'Transformation of Agriculture Sector Program 4 Phase 2',
#        'Tunisia Irrigated Agriculture Intensification Project',
#        'Burundi Early Grade Learning Project',
#        'Gas Storage Expansion Project',
#        'Modernizing Production of Statistics in Vietnam',
#        'Strengthening Foundations for Learning Project',
#        'Sao Tome and Principe: Institutional Capacity Building Project',
#        'China: Hubei Inland Waterway Improvement Project',
#        'Supporting Effective Universal Health Coverage in Argentina',
#        'Guinea Bissau: Safety Nets and Basic Services Project',
#        'Strengthening the Capacity of Regional Financial Institutions in the CEMAC Region',
#        'Social Safety Nets for Crisis Response',
#        'Strengthening Public Financial Management in Rajasthan',
#        'Agriculture Competitiveness Project',
#        'General Education Modernization Project',
#        'Cambodia Higher Education Improvement Project',
#        'Burkina Faso - West Africa Regional Communications Infrastructure Project - Additional Financing',
#        'Yemen Emergency Electricity Access Project',
#        'Emergency Agricultural Livelihoods and Climate Resilience Project',
#        'Strengthening Social Protection Project Additional Financing',
#        'Burundi Landscape Restoration and Resilience Project',
#        'Additional Financing II for Rural Electrification and Renewable Energy Development II',
#        'Palau:  ICT Sector Technical Assistance',
#        'CASA1000 Community Support Project - Kyrgyz Republic',
#        'Niger Skills Development for Growth Project Additional Financing',
#        'West Africa Coastal Areas Resilience Investment Project',
#        'Second Agriculture Sector Wide Approach Support Project',
#        'Mindanao Trust Fund-Reconstruction and Development Project Phase II',
#        'Community Access and Urban Services Enhancement Project',
#        'Mexico: Sustainable Productive Landscapes Project',
#        'Additional Financing for Energy Efficiency in Public Facilities Project  (PRESEMEH)',
#        'Burkina Faso - Bagre Growth Pole Project Additional Financing',
#        'Additional Financing for Second Serbia Health Project',
#        'The Gambia - Education Sector Support Program',
#        'Afghanistan Sehatmandi Project',
#        'Modernizing Afghan State-Owned Banks Project',
#        'Afghanistan Digital CASA Project',
#        "Cote d'Ivoire Land Policy Improvement and Implementation Project",
#        'Digital CASA - Kyrgyz Republic',
#        'Mali - Economic & Environmental Rehabilitation of the Niger River',
#        'Power Sector Recovery Project - Additional Financing',
#        'Supporting Gas Project Negotiations and Enhancing Institutional Capacities',
#        'Nicaragua Property Rights Strengthening Project',
#        'Support for the National Indigenous Peoples Development Plan',
#        'Meghalaya Community-led Landscapes Management Project',
#        'Natural Resources Governance Project in CAR',
#        'Ethiopia Electrification Program (ELEAP)',
#        'Madagascar Financial Inclusion Project',
#        'Rwanda Stunting Prevention and Reduction Project',
#        'Maharashtra Project on Climate Resilient Agriculture',
#        'Building Statistical Capacities in the Ministry of Education',
#        'Freetown Emergency Recovery Project',
#        'Albania Water Resources and Irrigation Project Additional Financing',
#        'AF Ethiopia Statistics for Results Project',
#        'Sustainable Low-Carbon Development in Orinoquia region Project',
#        'Moldova Education Reform Additional Financing',
#        'Iraq Social Fund for Development',
#        'Baghdad Water Supply and Sewerage Improvement Project',
#        'Cash Transfer Modernization Project',
#        'Social Safety Net Strengthening Project',
#        'Additional Financing for Social Protection System Project',
#        'Strengthening Entrepreneurship in Productive Forest Landscapes',
#        'Promoting Financial Inclusion Policies in Jordan',
#        'Philippine Rural Development Project Additional Financing',
#        'Zarafshon Irrigation Rehabilitation and Management Improvement Project',
#        'Lilongwe Water and Sanitation Project',
#        'Fiscal Performance Improvement Support Project (FSP):',
#        'National Transmission Modernization I Project',
#        'Salvador Social Multi-Sector Service Delivery Project',
#        'Strengthening Social Protection Project',
#        'Sustainable Energy Development Project',
#        'Jiangxi Farm Produce Distribution System Development',
#        'Capacity Building in Public Financial Management 2',
#        'Amazon Sustainable Landscapes Project',
#        'Employment Support Project for Syrians Under Temporary Protection and Turkish Citizens',
#        'Nepal Livestock Sector Innovation Project',
#        'Third Fiscal Consolidation, Sustainable Energy & Competitiveness DPF',
#        'Tamil Nadu Rural Transformation Project (TNRTP)',
#        'AF- Sustainable Management of Natural Resources and Climate Change',
#        'Additional Financing for Punjab Irrigated Agriculture Productivity Program Project',
#        'Brazil Investment Plan Coordination Project',
#        'Extractive Industries Technical Assistance Project Phase 2',
#        'Jordan Ozone Depleting Substances HCFC Phase-Out (ODS3) Phase 2',
#        'CAMEROON - Strengthening Public Sector Effectiveness and Statistical Capacity Project',
#        'Lesotho Transport Infrastructure and Connectivity Project (LTIC)',
#        "WAPP-APL4 (Phase 1): Côte d'Ivoire Liberia Sierra Leone and Guinea Regional Interconnector- Additional Financing",
#        'Tuvalu Aviation Investment Project Additional Finance III',
#        'Additional Financing Irrigation System Enhancement Project',
#        'Improving the Efficiency and Sustainability of Charcoal and Woodfuel Value Chains',
#        'East West Highway Corridor Improvement Project Additional Financing',
#        'Mining and Gas Technical Assistance Additional Financing',
#        'Additional Financing Forest Conservation and Sustainability in the Heart of the Colombian Amazon Project',
#        'China: Guangdong Compulsory Education Project', 'Project Name'],
#       dtype=object)

# %%
sns.scatterplot(data=df,x='Project Status',y='Region')
# Out:
# <AxesSubplot:xlabel='Project Status', ylabel='Region'>

# %%
# Import necessary libraries
import spacy

# Load the pre-trained NER model
nlp = spacy.load('en_core_web_sm')

# Load the data
data = df

# Define the function for extracting named entities from text
def extract_entities(text):
    doc = nlp(text)
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))
    return entities

# Apply the function to each column of text data
for column in data.columns:
    data[column+'_entities'] = data[column].apply(extract_entities)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# Load the data
df = data

# Group the data by country and year, and calculate the total budget for each group
budget_by_country = df.groupby(['Country', 'Year']).agg({'Total IDA and IBRD Commitment $US': 'Total Project Cost $US'})

# Line chart using matplotlib
budget_by_country = budget_by_country.reset_index().pivot(index='Year', columns='Country', values='Total Project Cost $US')
plt.plot(budget_by_country)
plt.xlabel('Year')
plt.ylabel('Total budget')
plt.legend(budget_by_country.columns)
plt.show()

# Bar chart using plotly
fig = px.bar(df, x='Year', y='Total Project Cost $US', color='Country', barmode='group')
fig.show()

# Pie chart using plotly
budget_by_country_year = df.groupby(['Country', 'Year']).agg({'Total Project Cost $US': 'sum'}).reset_index()
fig = px.pie(budget_by_country_year, values='Budget', names='Country', hole=0.5)
fig.show()

# Donut chart using plotly
fig = px.pie(budget_by_country_year, values='Total Project Cost $US', names='Country', hole=0.7)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
data
# Out:
#          Project Id                       Region  \
# 0           P161086                   South Asia
# 1           P173281  Latin America and Caribbean
# 2           P173746        East Asia and Pacific
# 3           P163836  Eastern and Southern Africa
# 4           P158079        East Asia and Pacific
# ...             ...                          ...
# 996   Not available  Eastern and Southern Africa
# 997   Not available      Europe and Central Asia
# 998   Not available  Eastern and Southern Africa
# 999   Not available  Latin America and Caribbean
# 1000  Not available        East Asia and Pacific
#
#                               Country Project Status  \
# 0     People's Republic of Bangladesh         Active
# 1                   Republic of Haiti         Active
# 2          People's Republic of China         Active
# 3                  Republic of Uganda         Active
# 4          People's Republic of China         Active
# ...                               ...            ...
# 996                Republic of Rwanda         Closed
# 997                           Georgia         Active
# 998            Republic of Mozambique         Closed
# 999              Republic of Colombia         Active
# 1000       People's Republic of China         Active
#
#                                            Project Name  \
# 0     Bangladesh: Enhancing Digital Government & Eco...
# 1     AF Haiti Rural Accessibility & Resilience Project
# 2     Emerging Infectious Diseases Prevention, Prepa...
# 3      Irrigation for Climate Resilience Project (ICRP)
# 4           China: Jiangxi Eco-industrial Parks Project
# ...                                                 ...
# 996   Improving the Efficiency and Sustainability of...
# 997   East West Highway Corridor Improvement Project...
# 998   Mining and Gas Technical Assistance Additional...
# 999   Additional Financing Forest Conservation and S...
# 1000      China: Guangdong Compulsory Education Project
#
#                           Project Development Objective  \
# 0     To improve the efficiency and cybersecurity of...
# 1     The Project Development Objectives are to: (i)...
# 2     The proposed project development objective is ...
# 3     To provide farmers in the project areas with a...
# 4     To strengthen Jiangxi’s institutional and regu...
# ...                                                 ...
# 996   The project development objective is to improv...
# 997   <p>The proposed PDOs are to: (i) reduce road u...
# 998   The proposed project development objective is ...
# 999   The project's global environmental objective (...
# 1000  The project development objective is to improv...
#
#                                     Implementing Agency  \
# 0                           Bangladesh Computer Council
# 1     Unite Technique d'Execution, Unite Centrale d'...
# 2     Ministry of Agriculture and Rural Affairs, Hai...
# 3                     Ministry of Water and Environment
# 4     Fuzhou New Industries Zone, Jiangxi Developmen...
# ...                                                 ...
# 996   Rwanda Environment Management Authority (REMA)...
# 997   Roads Department of the Ministry of Regional D...
# 998                                       Not available
# 999                                       Not available
# 1000                  Guangdong Department of Education
#
#      Consultant Services Required  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
# ...                           ...
# 996                           Yes
# 997                           Yes
# 998                           Yes
# 999                           Yes
# 1000                          Yes
#
#                                             Project URL Board Approval Date  \
# 0     https://projects.worldbank.org/en/projects-ope...       June 19, 2020
# 1     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 2     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 3     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# 4     https://projects.worldbank.org/en/projects-ope...       June 18, 2020
# ...                                                 ...                 ...
# 996   https://projects.worldbank.org/en/projects-ope...   November 14, 2017
# 997   https://projects.worldbank.org/en/projects-ope...    November 8, 2017
# 998   https://projects.worldbank.org/en/projects-ope...    November 1, 2017
# 999   https://projects.worldbank.org/en/projects-ope...    October 31, 2017
# 1000  https://projects.worldbank.org/en/projects-ope...    October 31, 2017
#
#       ... Financing Type_entities Total Project Cost $US_entities  \
# 0     ...                      []         [(305000000, CARDINAL)]
# 1     ...                      []                 [(0, CARDINAL)]
# 2     ...                      []         [(350000000, CARDINAL)]
# 3     ...                      []                 [(0, CARDINAL)]
# 4     ...                      []         [(400000000, CARDINAL)]
# ...   ...                     ...                             ...
# 996   ...                      []               [(3991436, DATE)]
# 997   ...                      []         [(130000000, CARDINAL)]
# 998   ...                      []          [(29000000, CARDINAL)]
# 999   ...                      []              [(12000000, DATE)]
# 1000  ...                      []             [(279400000, DATE)]
#
#      Total IDA and IBRD Commitment $US_entities Grant Amount $US_entities  \
# 0                       [(305000000, CARDINAL)]                        []
# 1                               [(0, CARDINAL)]                        []
# 2                       [(350000000, CARDINAL)]                        []
# 3                               [(0, CARDINAL)]                        []
# 4                       [(400000000, CARDINAL)]                        []
# ...                                         ...                       ...
# 996                           [(3991436, DATE)]                        []
# 997                     [(130000000, CARDINAL)]  [(90,000,000, CARDINAL)]
# 998                      [(29000000, CARDINAL)]                        []
# 999                          [(12000000, DATE)]                        []
# 1000                        [(279400000, DATE)]                        []
#
#                              Borrower_entities Lending Instrument_entities  \
# 0     [(People's Republic of Bangladesh, ORG)]                          []
# 1               [(The Republic of Haiti, GPE)]                          []
# 2          [(People's Republic of China, ORG)]                          []
# 3                              [(Uganda, GPE)]                          []
# 4          [(People's Republic of China, ORG)]                          []
# ...                                        ...                         ...
# 996                            [(Rwanda, GPE)]                          []
# 997                                         []                          []
# 998                                         []                          []
# 999                                         []                          []
# 1000       [(PEOPLE'S REPUBLIC OF CHINA, ORG)]                          []
#
#                      Sector 1_entities  \
# 0          [(Central Government, ORG)]
# 1           [(Inter-Urban Roads, ORG)]
# 2                                   []
# 3     [(Irrigation and Drainage, ORG)]
# 4                                   []
# ...                                ...
# 996        [(Fishing & Forestry, ORG)]
# 997         [(Inter-Urban Roads, ORG)]
# 998                                 []
# 999                                 []
# 1000                                []
#
#                                       Sector 2_entities  \
# 0     [(Public Administration - Information and Comm...
# 1       [(Public Administration - Transportation, ORG)]
# 2                           [(Fishing & Forestry, ORG)]
# 3             [(Agricultural Extension, Research, ORG)]
# 4                                                    []
# ...                                                 ...
# 996                                                  []
# 997     [(Public Administration - Transportation, ORG)]
# 998             [(Public Administration - Energy, ORG)]
# 999                         [(Fishing & Forestry, ORG)]
# 1000                                                 []
#
#                 Sector 3_entities Unnamed: 27_entities
# 0                    [(ICT, ORG)]                   []
# 1                              []                   []
# 2                              []                   []
# 3     [(Fishing & Forestry, ORG)]                   []
# 4                              []                   []
# ...                           ...                  ...
# 996                            []                   []
# 997                            []                   []
# 998                            []                   []
# 999                            []                   []
# 1000                 [(ICT, ORG)]                   []
#
# [1001 rows x 42 columns]

# %%
data.columns
# Out:
# Index(['Project Id', 'Region', 'Country', 'Project Status', 'Project Name',
#        'Project Development Objective', 'Implementing Agency',
#        'Consultant Services Required', 'Project URL', 'Board Approval Date',
#        'Project Closing Date', 'Financing Type', 'Total Project Cost $US',
#        'Total IDA and IBRD Commitment $US', 'Grant Amount $US', 'Borrower',
#        'Lending Instrument', 'Sector 1', 'Sector 2', 'Sector 3', 'Unnamed: 27',
#        'Project Id_entities', 'Region_entities', 'Country_entities',
#        'Project Status_entities', 'Project Name_entities',
#        'Project Development Objective_entities',
#        'Implementing Agency_entities', 'Consultant Services Required_entities',
#        'Project URL_entities', 'Board Approval Date_entities',
#        'Project Closing Date_entities', 'Financing Type_entities',
#        'Total Project Cost $US_entities',
#        'Total IDA and IBRD Commitment $US_entities',
#        'Grant Amount $US_entities', 'Borrower_entities',
#        'Lending Instrument_entities', 'Sector 1_entities', 'Sector 2_entities',
#        'Sector 3_entities', 'Unnamed: 27_entities'],
#       dtype='object')

# %%
data['Sector 1_entities'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0            [(Central Government, ORG)]
# 1             [(Inter-Urban Roads, ORG)]
# 2                                     []
# 3       [(Irrigation and Drainage, ORG)]
# 4                                     []
#                       ...
# 996          [(Fishing & Forestry, ORG)]
# 997           [(Inter-Urban Roads, ORG)]
# 998                                   []
# 999                                   []
# 1000                                  []
# Name: Sector 1_entities, Length: 1001, dtype: object>

# %%
# Get the names of the text columns and numeric columns
text_columns = list(data.select_dtypes(include=['object']).columns)
numeric_columns = list(data.select_dtypes(include=['float', 'int']).columns)

# Create separate DataFrames for the text columns and numeric columns
text_df = data[text_columns]
numeric_df = data[numeric_columns]

# %%
# Import necessary libraries
# !pip install transformers
import pandas as pd
import torch
from transformers import BertTokenizer, BertForTokenClassification

# Load the pre-trained BERT model and tokenizer
model = BertForTokenClassification.from_pretrained('bert-base-cased')
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Load the data
data = text_df

# Define the function for extracting named entities from text
def extract_entities(text):
    # Tokenize the text and add special tokens
    tokens = tokenizer.encode(text, add_special_tokens=True)
    # Get the token labels from the model
    with torch.no_grad():
        outputs = model(torch.tensor(tokens).unsqueeze(0))
        predictions = outputs[0].argmax(2).numpy()[0]
    # Convert the token labels back to named entities
    entities = []
    current_entity = ''
    current_label = ''
    for i, token in enumerate(tokens):
        label = predictions[i]
        if label == 0 or label == 2:  # ignore 'O' labels and 'CLS'/'SEP' tokens
            if current_entity != '':
                entities.append((current_entity.strip(), current_label))
                current_entity = ''
                current_label = ''
        if label == 1:  # 'B' label indicates start of a new entity
            if current_entity != '':
                entities.append((current_entity.strip(), current_label))
            current_entity = tokenizer.convert_ids_to_tokens([token])[0]
            current_label = 'B'
        if label == 3:  # 'I' label indicates continuation of an entity
            current_entity += ' ' + tokenizer.convert_ids_to_tokens([token])[0]
            current_label = 'I'
    if current_entity != '':
        entities.append((current_entity.strip(), current_label))
    return entities

# Apply the function to each column of text data
for column in data.columns:
    data[column+'_entities'] = data[column].apply(extract_entities)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.26.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Import necessary libraries
import pandas as pd
import torch
from transformers import BertTokenizer, BertForTokenClassification
from sklearn.metrics import f1_score, classification_report

# Load the pre-trained BERT model and tokenizer
model = BertForTokenClassification.from_pretrained('bert-base-cased')
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Load the data
train_data = text_df.sample(frac=0.8, random_state=42) # Use 80% of the data for training
test_data = text_df.drop(train_data.index) # Use the remaining 20% for testing


# Define the function for training and evaluating the model
def train_and_evaluate_model(train_data, test_data):
    # Tokenize the data
    train_tokens, train_labels = tokenize_data(train_data)
    test_tokens, test_labels = tokenize_data(test_data)
    # Train the model
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)
    for epoch in range(5):
        for i in range(len(train_tokens)):
            optimizer.zero_grad()
            outputs = model(torch.tensor(train_tokens[i]).unsqueeze(0), attention_mask=torch.tensor(train_tokens[i]).unsqueeze(0))
            loss = torch.nn.functional.cross_entropy(outputs[0], torch.tensor(train_labels[i]).unsqueeze(0))
            loss.backward()
            optimizer.step()
    # Evaluate the model
    model.eval()
    with torch.no_grad():
        predictions = []
        for tokens in test_tokens:
            outputs = model(torch.tensor(tokens).unsqueeze(0), attention_mask=torch.tensor(tokens).unsqueeze(0))
            predictions.append(outputs[0].argmax(2).numpy()[0])
        f1 = f1_score(flatten(test_labels), flatten(predictions), average='weighted')
        report = classification_report(flatten(test_labels), flatten(predictions))
        return f1, report

# Define the function for tokenizing the data
def tokenize_data(data):
    tokens = []
    labels = []
    for i, row in data.iterrows():
        text = row['text']
        label = row['label']
        tokenized = tokenizer.encode(text, add_special_tokens=True)
        token_labels = [0] * len(tokenized)
        label_tokens = tokenizer.encode(label, add_special_tokens=False)
        for j in range(len(tokenized)):
            if tokenized[j:j+len(label_tokens)] == label_tokens:
                token_labels[j] = 1
                for k in range(j+1, j+len(label_tokens)):
                    token_labels[k] = 2
        tokens.append(tokenized)
        labels.append(token_labels)
    return tokens, labels

# Flatten the nested lists of predictions and labels
def flatten(lst):
    return [item for sublist in lst for item in sublist]

# Split the CoNLL-2003 dataset into training and testing sets
#train_data = pd.read_csv('eng.train')
#test_data = pd.read_csv('eng.testa')

# Train and evaluate the model
f1, report = train_and_evaluate_model(train_data, test_data)

# Print the accuracy and classification report
print('F1 score:', f1)
print('Classification report:\n', report)

# %%
data.head(2)
